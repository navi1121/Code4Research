# %% [markdown]
# This example is for training a Noise2Void denoising model using RGB images. Images need to be in lossless format (e.g., png or tiff). JPG format is not allowed if you're using the DataGenerator object but you can use skimage or other ibraries to load them. The same approach can be used for grey-scale images, for example SEM or CT images.

# %%
#Install the tensorflow library suggested by N2V.
# !pip install tensorflow==2.10.0
# Out:
# Collecting tensorflow==2.10.0
#   Using cached tensorflow-2.10.0-cp39-cp39-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorflow==2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (3.11.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorflow==2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorflow==2.10.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (24.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorflow==2.10.0) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorflow==2.10.0) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorflow==2.10.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (1.64.1)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorflow==2.10.0) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.10.0) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.30.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (7.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.19.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.2.2)
# Using cached tensorflow-2.10.0-cp39-cp39-win_amd64.whl (455.9 MB)
# Installing collected packages: tensorflow
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.10.1
#     Uninstalling tensorflow-2.10.1:
#       Successfully uninstalled tensorflow-2.10.1
# Successfully installed tensorflow-2.10.0
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\bhana\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\bhana\anaconda3\envs\test\lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\bhana\AppData\Local\Temp\pip-uninstall-_60yfjxl'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\bhana\anaconda3\envs\test\Lib\site-packages\tensorflow\lite\~xperimental'.
#   You can safely remove it manually.

# %%
# !pip install n2v
# Out:
# Requirement already satisfied: n2v in c:\users\bhana\anaconda3\envs\test\lib\site-packages (0.3.3)
# Requirement already satisfied: numpy in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from n2v) (1.24.3)
# Requirement already satisfied: tifffile in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from n2v) (2024.6.18)
# Requirement already satisfied: imagecodecs>=2020.2.18 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from n2v) (2024.6.1)
# Requirement already satisfied: csbdeep<0.8.0,>=0.7.2 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from n2v) (0.7.4)
# Requirement already satisfied: Pillow in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from n2v) (10.3.0)
# Requirement already satisfied: ruamel.yaml>=0.16.10 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from n2v) (0.18.6)
# Requirement already satisfied: bioimageio.core in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from n2v) (0.6.7)
# Requirement already satisfied: scipy in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from csbdeep<0.8.0,>=0.7.2->n2v) (1.13.1)
# Requirement already satisfied: matplotlib in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from csbdeep<0.8.0,>=0.7.2->n2v) (3.9.0)
# Requirement already satisfied: six in c:\users\bhana\appdata\roaming\python\python39\site-packages (from csbdeep<0.8.0,>=0.7.2->n2v) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from csbdeep<0.8.0,>=0.7.2->n2v) (4.66.4)
# Requirement already satisfied: packaging in c:\users\bhana\appdata\roaming\python\python39\site-packages (from csbdeep<0.8.0,>=0.7.2->n2v) (24.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from ruamel.yaml>=0.16.10->n2v) (0.2.8)
# Requirement already satisfied: bioimageio.spec==0.5.3.* in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.core->n2v) (0.5.3.post4)
# Requirement already satisfied: fire in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.core->n2v) (0.6.0)
# Requirement already satisfied: imageio>=2.5 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.core->n2v) (2.34.2)
# Requirement already satisfied: loguru in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.core->n2v) (0.7.2)
# Requirement already satisfied: pydantic-settings in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.core->n2v) (2.3.3)
# Requirement already satisfied: pydantic in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.core->n2v) (2.7.4)
# Requirement already satisfied: python-dotenv in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.core->n2v) (1.0.1)
# Requirement already satisfied: requests in c:\users\bhana\appdata\roaming\python\python39\site-packages (from bioimageio.core->n2v) (2.32.3)
# Requirement already satisfied: ruyaml in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.core->n2v) (0.91.0)
# Requirement already satisfied: typing-extensions in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.core->n2v) (4.12.2)
# Requirement already satisfied: xarray in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.core->n2v) (2024.6.0)
# Requirement already satisfied: annotated-types<1,>=0.5.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.spec==0.5.3.*->bioimageio.core->n2v) (0.7.0)
# Requirement already satisfied: email-validator in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.spec==0.5.3.*->bioimageio.core->n2v) (2.2.0)
# Requirement already satisfied: pooch<2,>=1.5 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.spec==0.5.3.*->bioimageio.core->n2v) (1.8.2)
# Requirement already satisfied: python-dateutil in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from bioimageio.spec==0.5.3.*->bioimageio.core->n2v) (2.9.0.post0)
# Requirement already satisfied: rich in c:\users\bhana\appdata\roaming\python\python39\site-packages (from bioimageio.spec==0.5.3.*->bioimageio.core->n2v) (13.7.1)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from pydantic->bioimageio.core->n2v) (2.18.4)
# Requirement already satisfied: termcolor in c:\users\bhana\appdata\roaming\python\python39\site-packages (from fire->bioimageio.core->n2v) (2.4.0)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from loguru->bioimageio.core->n2v) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from loguru->bioimageio.core->n2v) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (6.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from requests->bioimageio.core->n2v) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from requests->bioimageio.core->n2v) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from requests->bioimageio.core->n2v) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from requests->bioimageio.core->n2v) (2024.6.2)
# Requirement already satisfied: distro>=1.3.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from ruyaml->bioimageio.core->n2v) (1.9.0)
# Requirement already satisfied: setuptools>=39.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from ruyaml->bioimageio.core->n2v) (69.5.1)
# Requirement already satisfied: pandas>=2.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from xarray->bioimageio.core->n2v) (2.2.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (3.19.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from pandas>=2.0->xarray->bioimageio.core->n2v) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from pandas>=2.0->xarray->bioimageio.core->n2v) (2024.1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from pooch<2,>=1.5->bioimageio.spec==0.5.3.*->bioimageio.core->n2v) (4.2.2)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\bhana\anaconda3\envs\test\lib\site-packages (from email-validator->bioimageio.spec==0.5.3.*->bioimageio.core->n2v) (2.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from rich->bioimageio.spec==0.5.3.*->bioimageio.core->n2v) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from rich->bioimageio.spec==0.5.3.*->bioimageio.core->n2v) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bhana\appdata\roaming\python\python39\site-packages (from markdown-it-py>=2.2.0->rich->bioimageio.spec==0.5.3.*->bioimageio.core->n2v) (0.1.2)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\bhana\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\bhana\anaconda3\envs\test\lib\site-packages)

# %%
import tensorflow as tf
import n2v
print(tf.__version__)
#print(n2v.__version__)
# Out:
# 2.10.0

# %%
# We import all our dependencies.
from n2v.models import N2VConfig, N2V
import numpy as np
from csbdeep.utils import plot_history
from n2v.utils.n2v_utils import manipulate_val_data
from n2v.internals.N2V_DataGenerator import N2V_DataGenerator
from matplotlib import pyplot as plt
import urllib
import os
import zipfile

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# **Training Data Preparation**
#
#
# <p>
# For training we can load a bunch of noisy images from a directory. Images can be of different sizes as we will be capturing them as a list, not an array. Of course, each image is an array. We will use the N2V_DataGenerator to extract training X and validation X_val patches.

# %%
# We create our DataGenerator-object.
# It will help us load data and extract patches for training and validation.
datagen = N2V_DataGenerator()

# %% [markdown]
# If you have many images stored in a directory, use load_imgs_from_directory method to load them into a list. Images can be of different sizes as we are capturing them into a list, not an array.
# <p>
# You can also use your favorite way of reading images (e.g., using skimage) sequentially and capturing them into a list that can be used as input to the network.
# <p>
# Note that the images need to be in float32 format. load_imgs_from_directory method converts images to float32 but if you use your own way of loading images, you need to make sure they are converted to float32.

# %%
#METHOD 1: Loading images using load_imgs_from_directory method
# We load all the '.png' files from the directory.
# The function will return a list of images (numpy arrays).
imgs = datagen.load_imgs_from_directory(directory = "Downloads/",
                                        filter='sky.png',dims='YXC')  #ZYX for 3D

# Let's look at the shape of the image
print('shape of loaded images: ',imgs[0].shape)
# If the image has four color channels (stored in the last dimension): RGB and Aplha.
# We are not interested in Alpha and will get rid of it.
imgs[0] = imgs[0][...,:3]
print('shape without alpha:    ',imgs[0].shape)
print('The data type of the first image is: ', imgs[0].dtype)
# Out:
# shape of loaded images:  (1, 510, 738, 4)
# shape without alpha:     (1, 510, 738, 3)
# The data type of the first image is:  float32

# %%
print(len(imgs))
print(imgs[0].shape)
print(imgs[0].dtype)
# Out:
# 1
# (1, 510, 738, 3)
# float32

# %%
# Let's look at the image.
plt.figure()
plt.imshow(imgs[0][0,:,:,:])
plt.show()

# %%
patch_size = 64

# %%
# Patches are extracted from all images and combined into a single numpy array
patch_shape = (patch_size,patch_size)
patches = datagen.generate_patches_from_list(imgs, shape=patch_shape)
# Out:
# Generated patches: (616, 64, 64, 3)

# %%
patches.shape
# Out:
# (616, 64, 64, 3)

# %%
# Patches are created so they do not overlap.
# (Note: this is not the case if you specify a number of patches. See the docstring for details!)
# Non-overlapping patches enable us to split them into a training and validation set.
train_val_split = int(patches.shape[0] * 0.8)
X = patches[:train_val_split]
X_val = patches[train_val_split:]

# %%
print(X.shape)
print(X.dtype)
print(X_val.shape)
# Out:
# (492, 64, 64, 3)
# float32
# (124, 64, 64, 3)

# %%
# Just in case: datagen.generate_patches_from_list?

# %%
# Let's look at two patches.
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.imshow(X[0,...])
plt.title('Training Patch');
plt.subplot(1,2,2)
plt.imshow(X_val[0,...])
plt.title('Validation Patch');

# %% [markdown]
# <h2>Configure</h2><p>
#
# Noise2Void comes with a special config-object, where we store network-architecture and training specific parameters. See the docstring of the N2VConfig constructor for a description of all parameters.
# <p>
# When creating the config-object, we provide the training data X. From X we extract mean and std that will be used to normalize all data before it is processed by the network. We also extract the dimensionality and number of channels from X.
# <p>
# Compared to supervised training (i.e. traditional CARE), we recommend to use N2V with an increased train_batch_size and batch_norm. To keep the network from learning the identity we have to manipulate the input pixels during training. For this we have the parameter n2v_manipulator with default value 'uniform_withCP'. Most pixel manipulators will compute the replacement value based on a neighborhood. With n2v_neighborhood_radius we can control its size.
# <p>
# <h3>Other pixel manipulators:</h3>
# <p>
# * normal_withoutCP: samples the neighborhood according to a normal gaussian distribution, but without the center pixel
# <br>
# * normal_additive: adds a random number to the original pixel value. The random number is sampled from a gaussian distribution with zero-mean and sigma = n2v_neighborhood_radius
# <br>
# * normal_fitted: uses a random value from a gaussian normal distribution with mean equal to the mean of the neighborhood and standard deviation equal to the standard deviation of the neighborhood.
# <br>
# * identity: performs no pixel manipulation
# <br>
# For faster training multiple pixels per input patch can be manipulated. In our experiments we manipulated about 0.198% of the input pixels per patch. For a patch size of 64 by 64 pixels this corresponds to about 8 pixels. This fraction can be tuned via n2v_perc_pix.
# <p>
# For Noise2Void training it is possible to pass arbitrarily large patches to the training method. From these patches random subpatches of size n2v_patch_shape are extracted during training. Default patch shape is set to (64, 64).
# <p>
# In the past we experienced bleedthrough artifacts between channels if training was terminated to early. To counter bleedthrough we added the single_net_per_channel option, which is turned on by default. In the back a single U-Net for each channel is created and trained independently, thereby removing the possiblity of bleedthrough.<br>
# Note: Essentially the network gets multiplied by the number of channels, which increases the memory requirements. If your GPU gets too small, you can always split the channels manually and train a network for each channel one after another.
# <p>
# **Warning:** to make this example notebook execute faster, we have set train_epochs to only 10.
# For better results we suggest 100 to 200 train_epochs.

# %%
# train_steps_per_epoch is set to (number of training patches)/(batch size), like this each training patch
# is shown once per epoch.
train_batch = 32
config = N2VConfig(X, unet_kern_size=3,
                   unet_n_first=64, unet_n_depth=3, train_steps_per_epoch=int(X.shape[0]/train_batch), train_epochs=35, train_loss='mse',
                   batch_norm=True, train_batch_size=train_batch, n2v_perc_pix=0.198, n2v_patch_shape=(patch_size, patch_size),
                   n2v_manipulator='uniform_withCP', n2v_neighborhood_radius=5, single_net_per_channel=False)

# Let's look at the parameters stored in the config-object.
vars(config)
# Out:
# {'means': ['0.25195014', '0.25308183', '0.2471036'],
#  'stds': ['0.04327373', '0.043311812', '0.047260452'],
#  'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 3,
#  'n_channel_out': 3,
#  'unet_residual': False,
#  'unet_n_depth': 3,
#  'unet_kern_size': 3,
#  'unet_n_first': 64,
#  'unet_last_activation': 'linear',
#  'unet_input_shape': (None, None, 3),
#  'train_loss': 'mse',
#  'train_epochs': 35,
#  'train_steps_per_epoch': 15,
#  'train_learning_rate': 0.0004,
#  'train_batch_size': 32,
#  'train_tensorboard': True,
#  'train_checkpoint': 'weights_best.h5',
#  'train_reduce_lr': {'factor': 0.5, 'patience': 10},
#  'batch_norm': True,
#  'n2v_perc_pix': 0.198,
#  'n2v_patch_shape': (64, 64),
#  'n2v_manipulator': 'uniform_withCP',
#  'n2v_neighborhood_radius': 5,
#  'single_net_per_channel': False,
#  'blurpool': False,
#  'skip_skipone': False,
#  'structN2Vmask': None,
#  'probabilistic': False}

# %%
# a name used to identify the model --> change this to something sensible!
model_name = 'n2v_2D_SKY'
# the base directory in which our model will live
basedir = 'models'
# We are now creating our network model.
model = N2V(config, model_name, basedir=basedir)

# %% [markdown]
# <h2>Training</h2><p>

# %%
# We are ready to start training now.
history = model.train(X, X_val)
# Out:
# 8 blind-spots will be generated per training patch of size (64, 64).
# Preparing validation data: 100%|████████████████████████████████████████████████████| 124/124 [00:00<00:00, 764.76it/s]
# Epoch 1/35
#  6/15 [===========>..................] - ETA: 1s - loss: 1.4483 - n2v_mse: 1.4483 - n2v_abs: 0.9097WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0558s vs `on_train_batch_end` time: 0.1120s). Check your callbacks.
# 3/3 [==============================] - 1s 7ms/step
# 15/15 [==============================] - 7s 274ms/step - loss: 1.0196 - n2v_mse: 1.0196 - n2v_abs: 0.7538 - val_loss: 0.8230 - val_n2v_mse: 0.8275 - val_n2v_abs: 0.6979 - lr: 4.0000e-04
# Epoch 2/35
# 3/3 [==============================] - 0s 11ms/step
# 15/15 [==============================] - 3s 201ms/step - loss: 0.4408 - n2v_mse: 0.4408 - n2v_abs: 0.4783 - val_loss: 0.7959 - val_n2v_mse: 0.8003 - val_n2v_abs: 0.6907 - lr: 4.0000e-04
# Epoch 3/35
# 3/3 [==============================] - 0s 12ms/step
# 15/15 [==============================] - 3s
35
# 3/3 [==============================] - 0s 11ms/step
# 15/15 [==============================] - 3s 181ms/step - loss: 0.0475 - n2v_mse: 0.0475 - n2v_abs: 0.1498 - val_loss: 0.9191 - val_n2v_mse: 0.9227 - val_n2v_abs: 0.7438 - lr: 2.0000e-04
# Epoch 29/35
# 15/15 [==============================] - ETA: 0s - loss: 0.0468 - n2v_mse: 0.0468 - n2v_abs: 0.1501
# Epoch 29: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 3/3 [==============================] - 0s 10ms/step
# 15/15 [==============================] - 3s 187ms/step - loss: 0.0468 - n2v_mse: 0.0468 - n2v_abs: 0.1501 - val_loss: 0.9202 - val_n2v_mse: 0.9230 - val_n2v_abs: 0.7450 - lr: 2.0000e-04
# Epoch 30/35
# 3/3 [==============================] - 0s 11ms/step
# 15/15 [==============================] - 3s 183ms/step - loss: 0.0457 - n2v_mse: 0.0457 - n2v_abs: 0.1468 - val_loss: 0.9380 - val_n2v_mse: 0.9417 - val_n2v_abs: 0.7504 - lr: 1.0000e-04
# Epoch 31/35
# 3/3 [==============================] - 0s 11ms/step
# 15/15 [==============================] - 3s 191ms/step - loss: 0.0429 - n2v_mse: 0.0429 - n2v_abs: 0.1458 - val_loss: 0.9387 - val_n2v_mse: 0.9422 - val_n2v_abs: 0.7520 - lr: 1.0000e-04
# Epoch 32/35
# 3/3 [==============================] - 0s 12ms/step
# 15/15 [==============================] - 3s 189ms/step - loss: 0.0432 - n2v_mse: 0.0432 - n2v_abs: 0.1453 - val_loss: 0.9402 - val_n2v_mse: 0.9436 - val_n2v_abs: 0.7538 - lr: 1.0000e-04
# Epoch 33/35
# 3/3 [==============================] - 0s 11ms/step
# 15/15 [==============================] - 3s 191ms/step - loss: 0.0440 - n2v_mse: 0.0440 - n2v_abs: 0.1468 - val_loss: 0.9541 - val_n2v_mse: 0.9575 - val_n2v_abs: 0.7591 - lr: 1.0000e-04
# Epoch 34/35
# 3/3 [==============================] - 0s 11ms/step
# 15/15 [==============================] - 3s 191ms/step - loss: 0.0396 - n2v_mse: 0.0396 - n2v_abs: 0.1452 - val_loss: 0.9610 - val_n2v_mse: 0.9644 - val_n2v_abs: 0.7612 - lr: 1.0000e-04
# Epoch 35/35
# 3/3 [==============================] - 0s 11ms/step
# 15/15 [==============================] - 3s 194ms/step - loss: 0.0400 - n2v_mse: 0.0400 - n2v_abs: 0.1412 - val_loss: 0.9697 - val_n2v_mse: 0.9730 - val_n2v_abs: 0.7638 - lr: 1.0000e-04
#
# Loading network weights from 'weights_best.h5'.

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss']);
# Out:
# ['loss', 'lr', 'n2v_abs', 'n2v_mse', 'val_loss', 'val_n2v_abs', 'val_n2v_mse']

# %% [markdown]
# <h1>Denoising images using the trained model</h1>

# %%
# We import all our dependencies.
from n2v.models import N2V
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.image import imread, imsave
from csbdeep.io import save_tiff_imagej_compatible

# %%
# A previously trained model is loaded by creating a new N2V-object without providing a 'config'.
model_name = 'n2v_2D_SKY'
basedir = 'models'
model = N2V(config=None, name=model_name, basedir=basedir)
# Out:
# Loading network weights from 'weights_best.h5'.

# %% [markdown]
# Denoising (prediction)

# %%
# We load the data we want to process.
img = imread('Downloads/sky.png')[:,:,:3]
img.dtype
# Out:
# dtype('float32')

# %%
# Here we denoise the image (predict)
# The parameter 'n_tiles' can be used if images are to big for the GPU memory.
# If we do not provide the n_tiles' parameter the system will automatically try to find an appropriate tiling.
# This can take longer.
pred = model.predict(img, axes='YXC')
# Out:
# 1/1 [==============================] - 0s 435ms/step

# %%
pred.shape
# Out:
# (510, 738, 3)

# %%
# Let's look at the results.
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.imshow(img)
plt.title('Input');
plt.subplot(1,2,2)
plt.imshow(pred)
plt.title('Prediction');

# %%
save_tiff_imagej_compatible('pred_train.tif', pred, axes='YXC')
